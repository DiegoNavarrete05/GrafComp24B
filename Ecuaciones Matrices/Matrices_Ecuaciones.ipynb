# %% [markdown]
# <img src="https://iieg.gob.mx/strategos/wp-content/uploads/2016/08/logo1.png" alt="Logo" width="300" height="150">
#
# Universidad Autónoma del Estado de México
#
# Centro Universitario UAEM Zumpango
#
# Ingeniería en Computación
#
# Graficación Computacional
#
# Alumno: Diego Argel Navarrete Godines
#
# Profesor: Hazem
#
# Fecha: 23 de octubre del 2024

# %% [markdown]
# # Matrices y sistemas de ecuaciones

# %% [markdown]
# import numpy as np
# A = np.matrix([[2, 3],[1, -2]])
# b = np.matrix([[8],[-10]])
# x = (A**-1)*b

# %% [markdown]
# ![01.jpg](attachment:b94758a7-d2c3-47c5-aca6-c6d0a33d97b1.jpg)

# %% [markdown]
# # Sistema de ecuaciones lineales

# %% [markdown]
# ##### Un sistema de \( n \) ecuaciones con \( n \) incógnitas se puede escribir de la siguiente forma:

# %% [markdown]
# ![02.jpg](attachment:feab8aea-1549-42b2-ac5a-3f894c870d3f.jpg)

# %% [markdown]
# ##### El sistema también se puede escribir en forma matricial de la forma:

# %% [markdown]
# ![03.jpg](attachment:086857f4-1167-47ee-94e4-f17783df9ce2.jpg)

# %% [markdown]
# Lo que se puede reescribir de forma compacta utilizando:
#
# $$
# A x = b
# $$
#
# donde \( A \) es una matriz de dimensión \( n \times n \) y \( x \) y \( b \) son dos vectores columna de longitud \( n \). En esta ecuación, se busca despejar el valor de \( x \). Para ello, asumiendo que la matriz \( A \) es regular, se puede multiplicar la expresión por la inversa de \( A \), es decir, \( A^{-1} \):
#
# $$
# A^{-1} A x = A^{-1} b
# $$
#
# En este caso, \( A^{-1} A \) es la matriz identidad, por lo que se puede escribir la solución del sistema como:
#
# $$
# x = A^{-1} b
# $$
#
# Esta operación es lo que se ha escrito anteriormente en el código Python. La matriz inversa de \( A \) se puede obtener mediante `A**-1` y, al multiplicar esta matriz por \( b \), se obtiene el resultado buscado.

# %% [markdown]
# # Determinar si el sistema se puede resolver

# %%
if np.linalg.det(A) == 0:
    x = None
    print("No se puede resolver")
else:
    x = (A**-1)*b

# %%
print("Matriz A: ", A)
print("Matriz B: ", b)
print("Inversa: ", x)
# Out:
# Matriz A:  [[ 2  3]
#  [ 1 -2]]
# Matriz B:  [[  8]
#  [-10]]
# Inversa:  [[-2.]
#  [ 4.]]

# %% [markdown]
# # Calcular determinantes en Python

# %% [markdown]
# ![04.jpeg](attachment:fc2a5908-b24e-429b-81b0-5229d5674a3d.jpeg)

# %%
A4 = np.matrix([[3, 2, -1], [2, -2, 4], [-1, 1/2, -1]])
b4 = np.matrix([[1],[-2],[0]])

print('Esto es A', A4)
print('Esto es b', b4)
# Out:
# Esto es A [[ 3.   2.  -1. ]
#  [ 2.  -2.   4. ]
#  [-1.   0.5 -1. ]]
# Esto es b [[ 1]
#  [-2]
#  [ 0]]

# %%
x = (A4**-1)*b4
print(x)
# Out:
# [[ 1.]
#  [-2.]
#  [-2.]]

# %%
print(np.linalg.det(A4))
# Out:
# -3.0000000000000036

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# # 1. A = (9)

# %%
import nyA = np.matrix([[9]])

print("this is A\n",A)
det = np.linalg.det(A)
print("this is the determinante\n",det)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 A = np.matrix([[9]])
#       3 print("this is A\n",A)
#       4 det = np.linalg.det(A)
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Determine la solución y el determinante para:

# %% [markdown]
# ![06.jpg](attachment:df4687f0-e936-4182-b79d-9e4e3cb34f01.jpg)

# %%
B = np.array ([[4,  -1],[-2,   0]])
print(B)
# Out:
# [[ 4 -1]
#  [-2  0]]

# %%
print("Determinante es: ", np.linalg.det (B))
# Out:
# Determinante es:  -2.0

# %% [markdown]
# ![05.jpg](attachment:482a74e5-4ebe-4656-9cb9-f4ef12c0b9d4.jpg)

# %%
C = np.array ([[5,   0,   2],[3,   1,   1],[0,   1,   2]])
print(C)
# Out:
# [[5 0 2]
#  [3 1 1]
#  [0 1 2]]

# %%
print("Determinante es: ", np.linalg.det (C))
# Out:
# Determinante es:  11.000000000000002
