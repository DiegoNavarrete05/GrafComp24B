# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 1.5, 2, 1], [1, 2, 1, 1])
plt.show()

# %%
plt.plot([1, 1, 2, 2, 1], [1, 2, 2, 1, 1])
plt.show()

# %%
plt.plot([1, 1.5, 2, 1], [1, 2, 1, 1])
plt.plot([1, 1, 2, 2, 1], [1, 2, 2, 1, 1])
plt.show()
